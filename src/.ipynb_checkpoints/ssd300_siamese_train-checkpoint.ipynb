# %%
import sys
sys.path.append('../')
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import glob

from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd300_Siamese import ssd_300
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms


img_height = 300 # Height of the model input images
img_width = 300 # Width of the model input images
img_channels = 3 # Number of color channels of the model input images
mean_color = [123, 117, 104] # Per-channel mean of images. Do not change if use any of the pre-trained weights.
# The color channel order in the original SSD is BGR,
# so we'll have the model reverse the color channel order of the input images.
swap_channels = [2, 1, 0]
classes = ['background',
           'person', 'rider', 'car', 'truck',
           'bus', 'train', 'motorcycle', 'bicycle']
n_classes = len(classes) - 1  # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO
# The anchor box scaling factors used in the original SSD300 for the Pascal VOC datasets
# scales_pascal = [0.1, 0.2, 0.37, 0.54, 0.71, 0.88, 1.05]
# The anchor box scaling factors used in the original SSD300 for the MS COCO datasets
scales_coco = [0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05]
scales = scales_coco
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]] # The anchor box aspect ratios used in the original SSD300; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 100, 300] # The space between two adjacent anchor box center points for each predictor layer.
# The offsets of the first anchor box center points from the top and left borders of the image
# as a fraction of the step size for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
clip_boxes = False # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
# The variances by which the encoded target coordinates are divided as in the original implementation
variances = [0.1, 0.1, 0.2, 0.2]
normalize_coords = True
Model_Build = 'New_Model'  # 'Load_Model'
Optimizer_Type = 'Adam' #  'SGD'  # 
batch_size = 16  # Change the batch size if you like, or if you run into GPU memory issues.
alpha_distance =  0.1  # Coefficient for the distance between the source and target feature maps.

if len(glob.glob('*.h5')):
    Dataset_Build = 'Load_Dataset'
else:
    Dataset_Build = 'New_Dataset'
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
if Model_Build == 'New_Model':
    # 1: Build the Keras model.

    K.clear_session()  # Clear previous models from memory.

    import tensorflow as tf
    from keras.backend.tensorflow_backend import set_session
    
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # (nothing gets printed in Jupyter, only if you run it standalone)
    sess = tf.Session(config=config)
    set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = ssd_300(image_size=(img_height, img_width, img_channels),
                    n_classes=n_classes,
                    mode='training',
                    l2_regularization=0.0005,
                    scales=scales,
                    aspect_ratios_per_layer=aspect_ratios,
                    two_boxes_for_ar1=two_boxes_for_ar1,
                    steps=steps,
                    offsets=offsets,
                    clip_boxes=clip_boxes,
                    variances=variances,
                    normalize_coords=normalize_coords,
                    subtract_mean=mean_color,
                    swap_channels=swap_channels)

    # 2: Load some weights into the model.

    # TODO: Set the path to the weights you want to load.
    weights_path = '../trained_weights/VGG_ILSVRC_16_layers_fc_reduced.h5'

    model.load_weights(weights_path, by_name=True)

    # 3: Instantiate an optimizer and the SSD loss function and compile the model.
    #    If you want to follow the original Caffe implementation, use the preset SGD
    #    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

    if Optimizer_Type == 'SGD':
        Optimizer = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)
    elif Optimizer_Type == 'Adam':
        Optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    else:
        raise ValueError('Undefined Optimizer_Type.')

    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0, alpha_distance=alpha_distance)

    model.compile(optimizer=Optimizer, loss={'conv9_2_norm_substract': ssd_loss.compute_distance_loss,
                                             'predictions': ssd_loss.compute_loss})

elif Model_Build == 'Load_Model':
    # TODO: Set the path to the `.h5` file of the model to be loaded.
    model_path = '../trained_weights/VGG_ssd300_Siamese_Cityscapes/epoch-23_loss-5.2110_val_loss-6.7452.h5'

    # We need to create an SSDLoss object in order to pass that to the model loader.
    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0, alpha_distance=alpha_distance)

    K.clear_session()  # Clear previous models from memory.

    import tensorflow as tf
    from keras.backend.tensorflow_backend import set_session
    
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # (nothing gets printed in Jupyter, only if you run it standalone)
    sess = tf.Session(config=config)
    set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = load_model(model_path, custom_objects={'AnchorBoxes': AnchorBoxes,
                                                   'L2Normalization': L2Normalization,
                                                   'compute_loss': ssd_loss.compute_loss,
                                                   'compute_distance_loss': ssd_loss.compute_distance_loss})
else:
    raise ValueError('Undefined Model_Build. Model_Build should be New_Model  or Load_Model')

# %%
if Dataset_Build == 'New_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

    train_dataset = DataGenerator(dataset='train', load_images_into_memory=False, hdf5_dataset_path=None)
    val_dataset = DataGenerator(dataset='val', load_images_into_memory=False, hdf5_dataset_path=None)

    # 2: Parse the image and label lists for the training and validation datasets. This can take a while.

    # TODO: Set the paths to the datasets here.

    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    Cityscapes_images_dir = '../../datasets/Cityscapes/JPEGImages'

    # The directories that contain the annotations.
    Cityscapes_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    Cityscapes_train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    Cityscapes_train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    Cityscapes_test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'

    # images_dirs, image_set_filenames, and annotations_dirs should have the same length
    train_dataset.parse_xml(images_dirs=[Cityscapes_images_dir,
                                         Cityscapes_images_dir],
                            image_set_filenames=[Cityscapes_train_source_image_set_filename,
                                                 Cityscapes_train_target_image_set_filename],
                            annotations_dirs=[Cityscapes_annotation_dir,
                                              Cityscapes_annotation_dir],
                            classes=classes,
                            include_classes='all',
                            exclude_truncated=False,
                            exclude_difficult=False,
                            ret=False)

    val_dataset.parse_xml(images_dirs=[Cityscapes_images_dir],
                          image_set_filenames=[Cityscapes_test_target_image_set_filename],
                          annotations_dirs=[Cityscapes_annotation_dir],
                          classes=classes,
                          include_classes='all',
                          exclude_truncated=False,
                          exclude_difficult=True,
                          ret=False)

    # Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
    # speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
    # option in the constructor, because in that cas the images are in memory already anyway. If you don't
    # want to create HDF5 datasets, comment out the subsequent two function calls.

    # After create these h5 files, if you have resized the input image, you need to reload these files. Otherwise,
    # the images and the labels will not change.

    resize_image_to = (300, 600)
    train_dataset.create_hdf5_dataset(file_path='dataset_cityscapes_train.h5',
                                      resize=resize_image_to,
                                      variable_image_size=True,
                                      verbose=True)

    val_dataset.create_hdf5_dataset(file_path='dataset_cityscapes_test.h5',
                                    resize=resize_image_to,
                                    variable_image_size=True,
                                    verbose=True)

    train_filename_paths = [Cityscapes_train_source_image_set_filename,
                            Cityscapes_train_target_image_set_filename]
    train_filenames = []
    for filename_path in train_filename_paths:
        with open(filename_path, 'r') as f:
            train_filenames.extend([os.path.join(Cityscapes_images_dir, line.strip()) for line in f])

    train_dataset = DataGenerator(dataset='train', 
                                  load_images_into_memory=False,
                                  hdf5_dataset_path='dataset_cityscapes_train.h5',
                                  filenames=train_filenames,
                                  filenames_type='text',
                                  images_dir=Cityscapes_images_dir)

    val_dataset = DataGenerator(dataset='val', 
                                load_images_into_memory=False,
                                hdf5_dataset_path='dataset_cityscapes_test.h5',
                                filenames=Cityscapes_test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=Cityscapes_images_dir)

elif Dataset_Build == 'Load_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Load dataset from the created h5 file.

    # The directories that contain the images.
    Cityscapes_images_dir = '../../datasets/Cityscapes/JPEGImages'

    # The paths to the image sets.
    Cityscapes_train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    Cityscapes_train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    Cityscapes_test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'

    train_filename_paths = [Cityscapes_train_source_image_set_filename,
                            Cityscapes_train_target_image_set_filename]
    train_filenames = []
    for filename_path in train_filename_paths:
        with open(filename_path, 'r') as f:
            train_filenames.extend([os.path.join(Cityscapes_images_dir, line.strip()) for line in f])

    train_dataset = DataGenerator(dataset='train', 
                                  load_images_into_memory=False,
                                  hdf5_dataset_path='dataset_cityscapes_train.h5',
                                  filenames=train_filenames,
                                  filenames_type='text',
                                  images_dir=Cityscapes_images_dir)

    val_dataset = DataGenerator(dataset='val', 
                                load_images_into_memory=False,
                                hdf5_dataset_path='dataset_cityscapes_test.h5',
                                filenames=Cityscapes_test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=Cityscapes_images_dir)

else:
    raise ValueError('Undefined Dataset_Build. Dataset_Build should be New_Dataset or Load_Dataset.')
# Out:
# Loading labels: 100%|██████████| 5932/5932 [00:01<00:00, 3187.98it/s]
# Loading image IDs: 100%|██████████| 5932/5932 [00:01<00:00, 5616.38it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 5932/5932 [00:00<00:00, 8124.57it/s]
# Loading labels: 100%|██████████| 493/493 [00:00<00:00, 3262.20it/s]
# Loading image IDs: 100%|██████████| 493/493 [00:00<00:00, 5561.68it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 493/493 [00:00<00:00, 8197.55it/s]

# %%
# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = SSDDataAugmentation(img_height=img_height,
                                            img_width=img_width,
                                            background=mean_color)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
# The input image and label are first processed by transformations. Then, the label will be further encoded by
# ssd_input_encoder. The encoded labels are classId and offset to each anchor box.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	  5932
# Number of images in the validation dataset:	   493

# %%
# def lr_schedule(epoch):
#     if epoch < 2:
#         return 0.0001
#     elif epoch < 60:
#         return 0.001
#     elif epoch < 100:
#         return 0.0001
#     else:
#         return 0.00001

def lr_schedule(epoch):
    if epoch < 40:
        return 0.001
    elif epoch < 100:
        return 0.0001
    else:
        return 0.00001

# Define model callbacks.
checkpoint_path = '../trained_weights/ssd_augm_alpha_distance_0_1'
if not os.path.exists(checkpoint_path):
    os.makedirs(checkpoint_path)

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath=os.path.join(checkpoint_path, 'epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5'),
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=False,
                                   save_weights_only=True,
                                   mode='auto',
                                   period=1)

# model_checkpoint.best to the best validation loss from the previous training
# model_checkpoint.best = 4.83704

csv_logger = CSVLogger(filename=os.path.join(checkpoint_path, 'ssd_augm_alpha_distance_0_1_training_log.csv'),
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan]

# %%
initial_epoch = 0
final_epoch = 120
steps_per_epoch = 1000

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/120
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 873s 873ms/step - loss: 9.6465 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 8.5433 - val_loss: 11.2926 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 10.5978
#
# Epoch 00001: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-01_loss-9.6473_val_loss-11.2926.h5
# Epoch 2/120
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 879s 879ms/step - loss: 6.9760 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 6.3796 - val_loss: 9.4551 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 8.9315
#
# Epoch 00002: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-02_loss-6.9759_val_loss-9.4551.h5
# Epoch 3/120
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 872s 872ms/step - loss: 6.4562 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.9690 - val_loss: 8.7475 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 8.2821
#
# Epoch 00003: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-03_loss-6.4561_val_loss-8.7475.h5
# Epoch 4/120
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 867s 867ms/step - loss: 6.2064 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.7577 - val_loss: 9.3050 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 8.8715
#
# Epoch 00004: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-04_loss-6.2067_val_loss-9.3050.h5
# Epoch 5/120
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 898s 898ms/step - loss: 6.0313 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.5994 - val_loss: 8.4671 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 8.0341
#
# Epoch 00005: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-05_loss-6.0310_val_loss-8.4671.h5
# Epoch 6/120
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 894s 894ms/step - loss: 5.9349 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.4998 - val_loss: 8.3773 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.9427
#
# Epoch 00006: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-06_loss-5.9347_val_loss-8.3773.h5
# Epoch 7/120
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 902s 902ms/step - loss: 5.8642 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.4242 - val_loss: 8.0363 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.5931
#
# Epoch 00007: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-07_loss-5.8638_val_loss-8.0363.h5
# Epoch 8/120
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 904s 904ms/step - loss: 5.8186 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.3765 - val_loss: 8.0302 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.5862
#
# Epoch 00008: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-08_loss-5.8187_val_loss-8.0302.h5
# Epoch 9/120
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 907s 907ms/step - loss: 5.7750 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.3233 - val_loss: 8.2822 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.8257
#
# Epoch 00009: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-09_loss-5.7747_val_loss-8.2822.h5
# Epoch 10/120
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 900s 900ms/step - loss: 5.6972 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.2433 - val_loss: 7.9313 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.4724
#
# Epoch 00010: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-10_loss-5.6973_val_loss-7.9313.h5
# Epoch 11/120
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 903s 903ms/step - loss: 5.6761 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.2194 - val_loss: 7.9898 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.5315
#
# Epoch 00011: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-11_loss-5.6757_val_loss-7.9898.h5
# Epoch 12/120
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 898s 898ms/step - loss: 5.6859 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.2267 - val_loss: 8.4215 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.9615
#
# Epoch 00012: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-12_loss-5.6858_val_loss-8.4215.h5
# Epoch 13/120
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 901s 901ms/step - loss: 5.6628 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.2000 - val_loss: 9.0506 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 8.5894
#
# Epoch 00013: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-13_loss-5.6624_val_loss-9.0506.h5
# Epoch 14/120
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 906s 906ms/step - loss: 5.6550 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.1945 - val_loss: 8.0036 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.5416
#
# Epoch 00014: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-14_loss-5.6544_val_loss-8.0036.h5
# Epoch 15/120
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 907s 907ms/step - loss: 5.6103 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.1510 - val_loss: 8.1524 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.6916
#
# Epoch 00015: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-15_loss-5.6106_val_loss-8.1524.h5
# Epoch 16/120
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 902s 902ms/step - loss: 5.5973 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.1382 - val_loss: 7.7818 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.3205
#
# Epoch 00016: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-16_loss-5.5972_val_loss-7.7818.h5
# Epoch 17/120
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 904s 904ms/step - loss: 5.5680 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.1069 - val_loss: 9.8132 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 9.3517
#
# Epoch 00017: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-17_loss-5.5680_val_loss-9.8132.h5
# Epoch 18/120
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 903s 903ms/step - loss: 5.5704 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.1087 - val_loss: 8.0033 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.5432
#
# Epoch 00018: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-18_loss-5.5703_val_loss-8.0033.h5
# Epoch 19/120
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 908s 908ms/step - loss: 5.5435 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.0852 - val_loss: 7.6061 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.1480
#
# Epoch 00019: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-19_loss-5.5437_val_loss-7.6061.h5
# Epoch 20/120
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 900s 900ms/step - loss: 5.5207 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.0612 - val_loss: 7.6168 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.1578
#
# Epoch 00020: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-20_loss-5.5210_val_loss-7.6168.h5
# Epoch 21/120
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 886s 886ms/step - loss: 5.5334 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.0760 - val_loss: 7.6676 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.2096
#
# Epoch 00021: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-21_loss-5.5334_val_loss-7.6676.h5
# Epoch 22/120
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 848s 848ms/step - loss: 5.5205 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.0600 - val_loss: 7.4474 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.9860
#
# Epoch 00022: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-22_loss-5.5203_val_loss-7.4474.h5
# Epoch 23/120
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 843s 843ms/step - loss: 5.5062 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.0466 - val_loss: 7.9280 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.4685
#
# Epoch 00023: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-23_loss-5.5060_val_loss-7.9280.h5
# Epoch 24/120
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 842s 842ms/step - loss: 5.4970 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.0373 - val_loss: 7.8187 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.3601
#
# Epoch 00024: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-24_loss-5.4969_val_loss-7.8187.h5
# Epoch 25/120
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 837s 837ms/step - loss: 5.5022 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.0414 - val_loss: 7.6186 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.1570
#
# Epoch 00025: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-25_loss-5.5025_val_loss-7.6186.h5
# Epoch 26/120
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 839s 839ms/step - loss: 5.4596 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.0006 - val_loss: 7.7099 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.2550
#
# Epoch 00026: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-26_loss-5.4596_val_loss-7.7099.h5
# Epoch 27/120
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 839s 839ms/step - loss: 5.4674 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.0084 - val_loss: 6.9988 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.5388
#
# Epoch 00027: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-27_loss-5.4673_val_loss-6.9988.h5
# Epoch 28/120
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 840s 840ms/step - loss: 5.4689 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.0097 - val_loss: 7.8155 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.3565
#
# Epoch 00028: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-28_loss-5.4690_val_loss-7.8155.h5
# Epoch 29/120
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 840s 840ms/step - loss: 5.4534 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9939 - val_loss: 7.2944 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.8347
#
# Epoch 00029: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-29_loss-5.4535_val_loss-7.2944.h5
# Epoch 30/120
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 849s 849ms/step - loss: 5.4471 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9862 - val_loss: 7.9244 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.4644
#
# Epoch 00030: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-30_loss-5.4468_val_loss-7.9244.h5
# Epoch 31/120
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 843s 843ms/step - loss: 5.4609 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.0009 - val_loss: 7.4185 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.9559
#
# Epoch 00031: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-31_loss-5.4607_val_loss-7.4185.h5
# Epoch 32/120
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 5.4717 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.0118 - val_loss: 7.1034 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.6444
#
# Epoch 00032: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-32_loss-5.4719_val_loss-7.1034.h5
# Epoch 33/120
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 847s 847ms/step - loss: 5.4713 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 5.0106 - val_loss: 8.0018 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.5420
#
# Epoch 00033: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-33_loss-5.4714_val_loss-8.0018.h5
# Epoch 34/120
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 848s 848ms/step - loss: 5.4322 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9735 - val_loss: 7.3378 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.8791
#
# Epoch 00034: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-34_loss-5.4318_val_loss-7.3378.h5
# Epoch 35/120
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 847s 847ms/step - loss: 5.4401 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9813 - val_loss: 7.3517 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.8938
#
# Epoch 00035: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-35_loss-5.4401_val_loss-7.3517.h5
# Epoch 36/120
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 843s 843ms/step - loss: 5.4453 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9867 - val_loss: 7.9113 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.4531
#
# Epoch 00036: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-36_loss-5.4447_val_loss-7.9113.h5
# Epoch 37/120
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 900s 900ms/step - loss: 5.4579 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9982 - val_loss: 7.5455 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.0857
#
# Epoch 00037: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-37_loss-5.4584_val_loss-7.5455.h5
# Epoch 38/120
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 907s 907ms/step - loss: 5.4470 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9872 - val_loss: 7.6041 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.1420
#
# Epoch 00038: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-38_loss-5.4473_val_loss-7.6041.h5
# Epoch 39/120
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 905s 905ms/step - loss: 5.4322 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9715 - val_loss: 7.9834 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.5230
#
# Epoch 00039: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-39_loss-5.4315_val_loss-7.9834.h5
# Epoch 40/120
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 910s 910ms/step - loss: 5.4317 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9698 - val_loss: 7.5464 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.0842
#
# Epoch 00040: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-40_loss-5.4317_val_loss-7.5464.h5
# Epoch 41/120
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 908s 908ms/step - loss: 5.4352 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9740 - val_loss: 7.9009 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.4420
#
# Epoch 00041: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-41_loss-5.4352_val_loss-7.9009.h5
# Epoch 42/120
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 905s 905ms/step - loss: 5.4195 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9610 - val_loss: 7.7356 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.2758
#
# Epoch 00042: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-42_loss-5.4200_val_loss-7.7356.h5
# Epoch 43/120
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 911s 911ms/step - loss: 5.4229 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9624 - val_loss: 8.2803 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.8200
#
# Epoch 00043: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-43_loss-5.4228_val_loss-8.2803.h5
# Epoch 44/120
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 908s 908ms/step - loss: 5.4498 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9882 - val_loss: 7.8071 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.3459
#
# Epoch 00044: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-44_loss-5.4496_val_loss-7.8071.h5
# Epoch 45/120
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 923s 923ms/step - loss: 5.3988 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9378 - val_loss: 8.3045 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.8421
#
# Epoch 00045: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-45_loss-5.3986_val_loss-8.3045.h5
# Epoch 46/120
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 926s 926ms/step - loss: 5.4031 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9423 - val_loss: 7.9278 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.4674
#
# Epoch 00046: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-46_loss-5.4030_val_loss-7.9278.h5
# Epoch 47/120
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 909s 909ms/step - loss: 5.4185 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9579 - val_loss: 7.7838 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.3231
#
# Epoch 00047: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-47_loss-5.4184_val_loss-7.7838.h5
# Epoch 48/120
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 907s 907ms/step - loss: 5.3890 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9287 - val_loss: 7.5308 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.0696
#
# Epoch 00048: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-48_loss-5.3891_val_loss-7.5308.h5
# Epoch 49/120
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 904s 904ms/step - loss: 5.3721 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9092 - val_loss: 8.0680 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.6078
#
# Epoch 00049: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-49_loss-5.3722_val_loss-8.0680.h5
# Epoch 50/120
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 908s 908ms/step - loss: 5.3922 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9301 - val_loss: 7.7157 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.2535
#
# Epoch 00050: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-50_loss-5.3924_val_loss-7.7157.h5
# Epoch 51/120
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 913s 913ms/step - loss: 5.4212 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9594 - val_loss: 8.8068 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 8.3445
#
# Epoch 00051: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-51_loss-5.4216_val_loss-8.8068.h5
# Epoch 52/120
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 911s 911ms/step - loss: 5.3688 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9077 - val_loss: 7.7617 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.3009
#
# Epoch 00052: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-52_loss-5.3689_val_loss-7.7617.h5
# Epoch 53/120
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 918s 918ms/step - loss: 5.3859 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9243 - val_loss: 7.4307 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.9684
#
# Epoch 00053: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-53_loss-5.3858_val_loss-7.4307.h5
# Epoch 54/120
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 957s 957ms/step - loss: 5.3778 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9154 - val_loss: 7.8005 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.3393
#
# Epoch 00054: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-54_loss-5.3776_val_loss-7.8005.h5
# Epoch 55/120
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 970s 970ms/step - loss: 5.3723 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9119 - val_loss: 7.8203 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.3590
#
# Epoch 00055: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-55_loss-5.3729_val_loss-7.8203.h5
# Epoch 56/120
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 922s 922ms/step - loss: 5.3969 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9353 - val_loss: 6.9129 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.4518
#
# Epoch 00056: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-56_loss-5.3971_val_loss-6.9129.h5
# Epoch 57/120
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 918s 918ms/step - loss: 5.3767 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9157 - val_loss: 6.8795 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.4189
#
# Epoch 00057: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-57_loss-5.3769_val_loss-6.8795.h5
# Epoch 58/120
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 914s 914ms/step - loss: 5.3941 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9330 - val_loss: 7.6794 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.2196
#
# Epoch 00058: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-58_loss-5.3940_val_loss-7.6794.h5
# Epoch 59/120
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 908s 908ms/step - loss: 5.3835 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9239 - val_loss: 7.5473 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 7.0864
#
# Epoch 00059: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-59_loss-5.3828_val_loss-7.5473.h5
# Epoch 60/120
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 947s 947ms/step - loss: 5.3726 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.9129 - val_loss: 7.2302 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.7714
#
# Epoch 00060: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-60_loss-5.3729_val_loss-7.2302.h5
# Epoch 61/120
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 984s 984ms/step - loss: 5.0907 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.6390 - val_loss: 6.8784 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.4337
#
# Epoch 00061: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-61_loss-5.0902_val_loss-6.8784.h5
# Epoch 62/120
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 904s 904ms/step - loss: 4.9950 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.5565 - val_loss: 6.6121 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.1796
#
# Epoch 00062: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-62_loss-4.9948_val_loss-6.6121.h5
# Epoch 63/120
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 907s 907ms/step - loss: 4.9384 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.5114 - val_loss: 6.5799 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.1582
#
# Epoch 00063: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-63_loss-4.9385_val_loss-6.5799.h5
# Epoch 64/120
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 904s 904ms/step - loss: 4.9219 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.5046 - val_loss: 6.6255 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.2124
#
# Epoch 00064: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-64_loss-4.9216_val_loss-6.6255.h5
# Epoch 65/120
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 911s 911ms/step - loss: 4.9081 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.4988 - val_loss: 6.5918 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.1862
#
# Epoch 00065: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-65_loss-4.9078_val_loss-6.5918.h5
# Epoch 66/120
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 915s 915ms/step - loss: 4.8898 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.4877 - val_loss: 6.6081 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.2093
#
# Epoch 00066: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-66_loss-4.8901_val_loss-6.6081.h5
# Epoch 67/120
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 914s 914ms/step - loss: 4.8704 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.4746 - val_loss: 6.5552 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.1623
#
# Epoch 00067: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-67_loss-4.8702_val_loss-6.5552.h5
# Epoch 68/120
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 968s 968ms/step - loss: 4.8180 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.4278 - val_loss: 6.5696 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.1820
#
# Epoch 00068: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-68_loss-4.8176_val_loss-6.5696.h5
# Epoch 69/120
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 965s 965ms/step - loss: 4.8237 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.4384 - val_loss: 6.6023 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.2194
#
# Epoch 00069: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-69_loss-4.8233_val_loss-6.6023.h5
# Epoch 70/120
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 1000s 1000ms/step - loss: 4.8323 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.4515 - val_loss: 6.6316 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.2530
#
# Epoch 00070: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-70_loss-4.8322_val_loss-6.6316.h5
# Epoch 71/120
#
# Epoch 00071: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 959s 959ms/step - loss: 4.8150 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.4383 - val_loss: 6.5912 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.2164
#
# Epoch 00071: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-71_loss-4.8153_val_loss-6.5912.h5
# Epoch 72/120
#
# Epoch 00072: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 938s 938ms/step - loss: 4.8035 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.4304 - val_loss: 6.7561 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.3848
#
# Epoch 00072: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-72_loss-4.8035_val_loss-6.7561.h5
# Epoch 73/120
#
# Epoch 00073: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 985s 985ms/step - loss: 4.7989 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.4293 - val_loss: 6.7406 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.3726
#
# Epoch 00073: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-73_loss-4.7987_val_loss-6.7406.h5
# Epoch 74/120
#
# Epoch 00074: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 972s 972ms/step - loss: 4.7913 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.4248 - val_loss: 6.5188 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.1538
#
# Epoch 00074: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-74_loss-4.7914_val_loss-6.5188.h5
# Epoch 75/120
#
# Epoch 00075: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 963s 963ms/step - loss: 4.7821 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.4186 - val_loss: 6.4670 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.1048
#
# Epoch 00075: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-75_loss-4.7819_val_loss-6.4670.h5
# Epoch 76/120
#
# Epoch 00076: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 976s 976ms/step - loss: 4.7644 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.4036 - val_loss: 6.6107 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.2511
#
# Epoch 00076: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-76_loss-4.7644_val_loss-6.6107.h5
# Epoch 77/120
#
# Epoch 00077: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 960s 960ms/step - loss: 4.7579 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.3995 - val_loss: 6.4732 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.1161
#
# Epoch 00077: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-77_loss-4.7577_val_loss-6.4732.h5
# Epoch 78/120
#
# Epoch 00078: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 961s 961ms/step - loss: 4.7336 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.3777 - val_loss: 6.6551 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.3004
#
# Epoch 00078: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-78_loss-4.7337_val_loss-6.6551.h5
# Epoch 79/120
#
# Epoch 00079: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 958s 958ms/step - loss: 4.7500 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.3965 - val_loss: 6.6707 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.3182
#
# Epoch 00079: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-79_loss-4.7499_val_loss-6.6707.h5
# Epoch 80/120
#
# Epoch 00080: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 923s 923ms/step - loss: 4.7455 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.3939 - val_loss: 6.7669 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.4164
#
# Epoch 00080: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-80_loss-4.7457_val_loss-6.7669.h5
# Epoch 81/120
#
# Epoch 00081: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 865s 865ms/step - loss: 4.7683 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.4187 - val_loss: 6.3628 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.0143
#
# Epoch 00081: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-81_loss-4.7683_val_loss-6.3628.h5
# Epoch 82/120
#
# Epoch 00082: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 846s 846ms/step - loss: 4.7517 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.4040 - val_loss: 6.6213 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.2745
#
# Epoch 00082: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-82_loss-4.7516_val_loss-6.6213.h5
# Epoch 83/120
#
# Epoch 00083: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 841s 841ms/step - loss: 4.7070 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.3609 - val_loss: 6.6235 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.2782
#
# Epoch 00083: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-83_loss-4.7071_val_loss-6.6235.h5
# Epoch 84/120
#
# Epoch 00084: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 841s 841ms/step - loss: 4.7165 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.3721 - val_loss: 6.6635 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.3197
#
# Epoch 00084: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-84_loss-4.7163_val_loss-6.6635.h5
# Epoch 85/120
#
# Epoch 00085: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 839s 839ms/step - loss: 4.7238 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.3809 - val_loss: 6.6577 - val_conv9_2_norm_substract_loss: 0.0000e+00 - val_predictions_loss: 6.3154
#
# Epoch 00085: saving model to ../trained_weights/VGG_ssd300_Cityscapes/epoch-85_loss-4.7242_val_loss-6.6577.h5
# Epoch 86/120
#
# Epoch 00086: LearningRateScheduler setting learning rate to 0.0001.
#  629/1000 [=================>............] - ETA: 5:08 - loss: 4.7207 - conv9_2_norm_substract_loss: 0.0000e+00 - predictions_loss: 4.3788
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-ea67b764e796> in <module>()
#       9                               validation_data=val_generator,
#      10                               validation_steps=ceil(val_dataset_size/batch_size),
# ---> 11                               initial_epoch=initial_epoch)
#
# /usr/local/lib/python3.5/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2719                     'In order to feed symbolic tensors to a Keras model '
#    2720                     'in TensorFlow, you need tensorflow 1.8 or higher.')
# -> 2721             return self._legacy_call(inputs)
#    2722
#    2723
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in _legacy_call(self, inputs)
#    2691         session = get_session()
#    2692         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2693                               **self.session_kwargs)
#    2694         return updated[:len(self.outputs)]
#    2695
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# 1: Set the generator for the val_dataset or train_dataset predictions.

predict_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[convert_to_3_channels,
                                                          resize],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
i = 3  # Which batch item to look at

print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))

# 3: Make predictions.

y_pred = model.predict(batch_images)[-1]

# Now let's decode the raw predictions in `y_pred`.

# Had we created the model in 'inference' or 'inference_fast' mode,
# then the model's final layer would be a `DecodeDetections` layer and
# `y_pred` would already contain the decoded predictions,
# but since we created the model in 'training' mode,
# the model outputs raw predictions that still need to be decoded and filtered.
# This is what the `decode_detections()` function is for.
# It does exactly what the `DecodeDetections` layer would do,
# but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).

# `decode_detections()` with default argument values follows the procedure of the original SSD implementation:
# First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes,
# then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45,
# and out of what is left after that, the top 200 highest confidence boxes are returned.
# Those settings are for precision-recall scoring purposes though.
# In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5,
# since we're only interested in the very confident predictions.

# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.35,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# We made the predictions on the resized images,
# but we'd like to visualize the outcome on the original input images,
# so we'll convert the coordinates accordingly.
# Don't worry about that opaque `apply_inverse_transforms()` function below,
# in this simple case it just applies `(* original_image_size / resized_image_size)` to the box coordinates.

# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])

# Finally, let's draw the predicted boxes onto the image.
# Each predicted box says its confidence next to the category name.
# The ground truth boxes are also drawn onto the image in green for comparison.

# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()
classes = ['background',
           'person', 'rider', 'car', 'truck',
           'bus', 'train', 'motorcycle', 'bicycle']

plt.figure(figsize=(20, 12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': 'green', 'alpha': 1.0})

for box in y_pred_decoded_inv[i]:
    xmin = box[2]
    ymin = box[3]
    xmax = box[4]
    ymax = box[5]
    color = colors[int(box[0])]
    label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': color, 'alpha': 1.0})
